# %%
import matplotlib.pyplot as plt

from superfv import OutputLoader, plot_2d_slice

# %%
sim = OutputLoader("/scratch/gpfs/jp7427/out/double-mach-reflection/MUSCL-Hancock")

fig, ax = plt.subplots(figsize=(12, 4))

plot_2d_slice(sim, ax, "rho", cell_averaged=True)

ax.set_xlim(0, 3)
# Out:
# Successfully read simulation output from "/scratch/gpfs/jp7427/out/double-mach-reflection/MUSCL-Hancock"
# (0.0, 3.0)

# %%
sim = OutputLoader("/scratch/gpfs/jp7427/out/double-mach-reflection/ZS3")

fig, ax = plt.subplots(figsize=(12, 4))

plot_2d_slice(sim, ax, "rho", cell_averaged=True)

ax.set_xlim(0, 3)
# Out:
# Successfully read simulation output from "/scratch/gpfs/jp7427/out/double-mach-reflection/ZS3"
# (0.0, 3.0)

# %%
sim = OutputLoader("/scratch/gpfs/jp7427/out/double-mach-reflection/ZS3-T")

fig, ax = plt.subplots(figsize=(12, 4))

plot_2d_slice(sim, ax, "rho", cell_averaged=True)

ax.set_xlim(0, 3)
# Out:
# Successfully read simulation output from "/scratch/gpfs/jp7427/out/double-mach-reflection/ZS3-T"
# (0.0, 3.0)

# %%
sim = OutputLoader("/scratch/gpfs/jp7427/out/double-mach-reflection/MM3(0.1)")

fig, ax = plt.subplots(figsize=(12, 4))

plot_2d_slice(sim, ax, "rho", cell_averaged=True)

ax.set_xlim(0, 3)
# Out:
# Successfully read simulation output from "/scratch/gpfs/jp7427/out/double-mach-reflection/MM3(0.1)"
# (0.0, 3.0)

# %%
sim = OutputLoader("/scratch/gpfs/jp7427/out/double-mach-reflection/MM3(0.1)")

fig, ax = plt.subplots(figsize=(12, 4))

plot_2d_slice(sim, ax, "troubles", cmap="Reds")

ax.set_xlim(0, 3)
# Out:
# Successfully read simulation output from "/scratch/gpfs/jp7427/out/double-mach-reflection/MM3(0.1)"
# (0.0, 3.0)

# %%
sim = OutputLoader("/scratch/gpfs/jp7427/out/double-mach-reflection/MM3(0.01)")

fig, ax = plt.subplots(figsize=(12, 4))

plot_2d_slice(sim, ax, "rho", cell_averaged=True)

ax.set_xlim(0, 3)
# Out:
# Successfully read simulation output from "/scratch/gpfs/jp7427/out/double-mach-reflection/MM3(0.01)"
# (0.0, 3.0)

# %%
sim = OutputLoader("/scratch/gpfs/jp7427/out/double-mach-reflection/MM3(0.01)")

fig, ax = plt.subplots(figsize=(12, 4))

plot_2d_slice(sim, ax, "troubles", cmap="Reds")

ax.set_xlim(0, 3)
# Out:
# Successfully read simulation output from "/scratch/gpfs/jp7427/out/double-mach-reflection/MM3(0.01)"
# (0.0, 3.0)
