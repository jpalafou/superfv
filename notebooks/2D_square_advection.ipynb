# %%
from superfv import AdvectionSolver, initial_conditions
from functools import partial
import matplotlib.pyplot as plt
import numpy as np

# %%
solver = AdvectionSolver(
    ic=partial(initial_conditions.square, vx=2, vy=1),
    nx=32,
    ny=32,
    p=3,
    interpolation_scheme="gauss-legendre",
    ZS=True,
    PAD={"rho": (0, 1)},
)
solver.run(1.0)
# Out:
#   0%|          | 0/1.0 [00:00]
# (4, 36, 36, 1, 4) (4, 36, 36, 1, 4)
# (4, 36, 36, 1, 4) (4, 36, 36, 1, 4)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       1 solver = AdvectionSolver(
#       2     ic=partial(initial_conditions.square, vx=2, vy=1),
#       3     nx=32,
#    (...)
#       8     PAD={"rho": (0, 1)},
#       9 )
# ---> 10 solver.run(1.0)
#
# File ~/Desktop/superfv/superfv/tools/timer.py:14, in method_timer.<locals>.wrapper(self, *args, **kwargs)
#      12 if not ALREADY_RUNNING:
#      13     self.timer.start(cat)
# ---> 14 result = method(self, *args, **kwargs)
#      15 if not ALREADY_RUNNING:
#      16     self.timer.stop(cat)
#
# File ~/Desktop/superfv/superfv/finite_volume_solver.py:1084, in FiniteVolumeSolver.run(self, *args, **kwargs)
#    1082     self.ssprk3(*args, **kwargs)
#    1083 case 3:
# -> 1084     self.rk4(*args, **kwargs)
#    1085 case _:
#    1086     raise ValueError(f"Runge-Kutta method not implemented for {q=}")
#
# File ~/Desktop/superfv/superfv/explicit_ODE_solver.py:367, in ExplicitODESolver.rk4(self, *args, **kwargs)
#     364     return dt, unext
#     366 self.stepper = stepper
# --> 367 self.integrate(*args, **kwargs)
#
# File ~/Desktop/superfv/superfv/tools/timer.py:14, in method_timer.<locals>.wrapper(self, *args, **kwargs)
#      12 if not ALREADY_RUNNING:
#      13     self.timer.start(cat)
# ---> 14 result = method(self, *args, **kwargs)
#      15 if not ALREADY_RUNNING:
#      16     self.timer.stop(cat)
#
# File ~/Desktop/superfv/superfv/explicit_ODE_solver.py:257, in ExplicitODESolver.integrate(self, T, n, log_every_step, snapshot_dir, overwrite)
#     255 self.timer.start("!ODE_INT")
#     256 while self.t < T_max:
# --> 257     self.take_step(target_time=target_time)
#     258     self.progress_bar_action(action="update")
#     260     # mini snapshot
#
# File ~/Desktop/superfv/superfv/explicit_ODE_solver.py:286, in ExplicitODESolver.take_step(self, target_time)
#     284 self.substep_count = 0
#     285 self.step_count += 1
# --> 286 dt, ynext = self.stepper(
#     287     self.t, self.arrays[self._state], target_time=target_time
#     288 )
#     289 self.t += dt
#     290 self.arrays[self._state] = ynext
#
# File ~/Desktop/superfv/superfv/explicit_ODE_solver.py:358, in ExplicitODESolver.rk4.<locals>.stepper(t, u, target_time)
#     357 def stepper(t, u, target_time=None):
# --> 358     dt, k0 = self.f(t, u)
#     359     dt = _dt_ceil(t=t, dt=dt, t_max=target_time)
#     360     _, k1 = self.f(t + 0.5 * dt, u + 0.5 * dt * k0)
#
# File ~/Desktop/superfv/superfv/tools/timer.py:14, in method_timer.<locals>.wrapper(self, *args, **kwargs)
#      12 if not ALREADY_RUNNING:
#      13     self.timer.start(cat)
# ---> 14 result = method(self, *args, **kwargs)
#      15 if not ALREADY_RUNNING:
#      16     self.timer.stop(cat)
#
# File ~/Desktop/superfv/superfv/finite_volume_solver.py:596, in FiniteVolumeSolver.f(self, t, u)
#     583 """
#     584 Compute the right-hand side of the ODE.
#     585
#    (...)
#     593         (nvars, nx, ny, nz).
#     594 """
#     595 self.substep_count += 1
# --> 596 dt, fluxes = self.compute_dt_and_fluxes(
#     597     t=t,
#     598     u=u,
#     599     mode=self.interpolation_scheme,
#     600     p=self.p,
#     601     limiting_scheme=self.a_priori_slope_limiting_scheme,
#     602     slope_limiter=self.a_priori_slope_limiter,
#     603 )
#     604 if self.MOOD and not (self.ZS_adaptive_timestep and self.substep_count > 1):
#     605     dt, fluxes = self.MOOD_loop(t, dt, u, fluxes)
#
# File ~/Desktop/superfv/superfv/tools/timer.py:14, in method_timer.<locals>.wrapper(self, *args, **kwargs)
#      12 if not ALREADY_RUNNING:
#      13     self.timer.start(cat)
# ---> 14 result = method(self, *args, **kwargs)
#      15 if not ALREADY_RUNNING:
#      16     self.timer.stop(cat)
#
# File ~/Desktop/superfv/superfv/advection_solver.py:265, in AdvectionSolver.compute_dt_and_fluxes(self, t, u, mode, p, limiting_scheme, slope_limiter)
#     263     fluxes.append(None)
#     264     continue
# --> 265 xl, xr = self.interpolate_face_nodes(
#     266     u_padded,
#     267     dim=dim,
#     268     interpolation_scheme=mode,
#     269     limiting_scheme=limiting_scheme,
#     270     p=_p,
#     271     slope_limiter=slope_limiter,
#     272 )
#     273 F = self.compute_numerical_fluxes(
#     274     xr[_slc(**{dim: (None, -1)})],
#     275     xl[_slc(**{dim: (1, None)})],
#    (...)
#     278     p=_p,
#     279 )
#     280 fluxes.append(F)
#
# File ~/Desktop/superfv/superfv/tools/timer.py:14, in method_timer.<locals>.wrapper(self, *args, **kwargs)
#      12 if not ALREADY_RUNNING:
#      13     self.timer.start(cat)
# ---> 14 result = method(self, *args, **kwargs)
#      15 if not ALREADY_RUNNING:
#      16     self.timer.stop(cat)
#
# File ~/Desktop/superfv/superfv/finite_volume_solver.py:893, in FiniteVolumeSolver.interpolate_face_nodes(self, averages, dim, interpolation_scheme, limiting_scheme, p, slope_limiter, clear_cache)
#     886     return muscl(
#     887         averages,
#     888         dim=dim,
#     889         slope_limiter=minmod if slope_limiter == "minmod" else moncen,
#     890     )
#     891 elif limiting_scheme == "zhang-shu":
#     892     # early escape with Zhang-Shu scheme
# --> 893     return self.zhang_shu_limiter(
#     894         averages,
#     895         dim=dim,
#     896         interpolation_scheme=cast(
#     897             Literal["transverse", "gauss-legendre"], interpolation_scheme
#     898         ),
#     899         p=cast(int, p),
#     900     )
#     901 else:
#     902     raise ValueError(
#     903         f"Unsupported interpolation and limiting schemes: {interpolation_scheme}, {limiting_scheme}."
#     904     )
#
# File ~/Desktop/superfv/superfv/advection_solver.py:202, in AdvectionSolver.zhang_shu_limiter(self, averages, dim, interpolation_scheme, p)
#     180 def zhang_shu_limiter(
#     181     self,
#     182     averages: ArrayLike,
#    (...)
#     185     p: int,
#     186 ) -> Tuple[ArrayLike, ArrayLike]:
#     187     """
#     188     Returns a slope-limited interpolation using Zhang and Shu's
#     189     maximum-principle-satisfying slope limiter.
#    (...)
#     200             shape (nvars, <nx, <ny, <nz).
#     201     """
# --> 202     return zhang_shu_advection(self, averages, dim, interpolation_scheme, p)
#
# File ~/Desktop/superfv/superfv/slope_limiting/zhang_and_shu.py:161, in zhang_shu_advection(fv_solver, averages, dim, interpolation_scheme, p, tol)
#     159         update_min_and_max(left)
#     160         update_min_and_max(right)
# --> 161 STOP
#     163 # compute theta
#     164 theta = np.ones_like(foc)
#
# NameError: name 'STOP' is not defined

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
solver.plot_1d_slice(ax, "rho", x=None, y=0.5)
# Out:
# /Users/jonathan/Desktop/superfv/superfv/visualization.py:32: UserWarning: Coordinate 0.5 not found in array. Using nearest: 0.484375.
#   warnings.warn(

# %%
print(np.min(solver.minisnapshots["min_rho"]), np.max(solver.minisnapshots["max_rho"]))
# Out:
# 0.0 1.0
