# %%
from superfv import AdvectionSolver, initial_conditions
from functools import partial
import matplotlib.pyplot as plt
import numpy as np

# %%
solver = AdvectionSolver(
    ic=partial(initial_conditions.square, vx=2, vy=1),
    nx=128,
    ny=128,
    p=3,
    interpolation_scheme="transverse",
    MOOD=True,
    NAD=1e-5,
    PAD={"rho": (0, 1)},
    adaptive_timestepping=False,
    cupy=True,
)
solver.run(1.0, q_max=2)
# Out:
# 100%|██████████| 1.0/1.0 [00:14]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
solver.plot_1d_slice(ax, "rho", x=None, y=0.5)
# Out:
# /home/jp7427/Desktop/superfv/superfv/visualization.py:32: UserWarning: Coordinate 0.5 not found in array. Using nearest: 0.49609375.
#   warnings.warn(

# %%
print(np.min(solver.minisnapshots["min_rho"]), np.max(solver.minisnapshots["max_rho"]))
# Out:
# -0.00046006637850606126 1.0013231846495914
