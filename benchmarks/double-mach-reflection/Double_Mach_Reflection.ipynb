# %%
import matplotlib.pyplot as plt

from superfv import OutputLoader, plot_2d_slice

# %%
sim1 = OutputLoader("/scratch/gpfs/jp7427/out/kelvin-helmholtz/ZS7")
# Out:
# Successfully read simulation output from "/scratch/gpfs/jp7427/out/kelvin-helmholtz/ZS7"

# %%
sim2 = OutputLoader("/scratch/gpfs/jp7427/out/kelvin-helmholtz/MM7(1e-1)")
# Out:
# Successfully read simulation output from "/scratch/gpfs/jp7427/out/kelvin-helmholtz/MM7(1e-1)"

# %%
sim0 = OutputLoader("/scratch/gpfs/jp7427/out/kelvin-helmholtz/MUSCL-Hancock")
# Out:
# Successfully read simulation output from "/scratch/gpfs/jp7427/out/kelvin-helmholtz/MUSCL-Hancock"

# %%
fig, ax = plt.subplots()
ax.set_xlim(2, 3)

plot_2d_slice(sim0, ax, "rho", cell_averaged=True)
# Out:
# (<matplotlib.image.AxesImage at 0x151bdb05d6a0>, None)
